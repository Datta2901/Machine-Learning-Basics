# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv("Salary_Data.csv")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.shape
# Out:
# (30, 2)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0>

# %%
X = data["YearsExperience"]
Y = data["Salary"]

# %%
X = np.array(X)
Y = np.array(Y)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
X_train=X_train.reshape(-1,1)
Y_train=Y_train.reshape(-1,1)
X_test=X_test.reshape(-1,1)
Y_test=Y_test.reshape(-1,1)

# %%
model = KNeighborsRegressor(n_neighbors=3)
model.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
Y_predicted = model.predict(X_test)

# %%
Y_predicted
# Out:
# array([[ 60229.66666667],
#        [116263.66666667],
#        [ 95660.        ],
#        [ 60412.33333333],
#        [113404.        ],
#        [ 58656.33333333]])

# %%
Y_test
# Out:
# array([[ 61111.],
#        [112635.],
#        [ 98273.],
#        [ 54445.],
#        [105582.],
#        [ 57081.]])

# %%
plt.scatter(X_train,Y_train,color = 'red')
plt.scatter(X_train,model.predict(X_train),color = "blue")
plt.title("Knn Regression For Salary-employee --> Line Of Best Fit")
plt.xlabel("Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
